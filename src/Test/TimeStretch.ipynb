# %%
import os
audio_path = os.path.expanduser('~/FMA/fma_small/fma_small/000/')
audio_path_2x = os.path.expanduser('~/FMA/fma_small/fma_small_0.5x/000/')

# %%
import librosa
import IPython.display as ipd
import numpy as np
x, sr = librosa.load(audio_path + '000002.mp3', sr=None, mono=False)
x_2x, sr_2x = librosa.load(audio_path_2x + '000002.mp3', sr=None, mono=False)
print(x.shape)
print(x_2x.shape)
print(sr)
print(sr_2x)
print()
ipd.Audio(x[:, :sr*4], rate=sr)
# Out:
# /home/b073040018/.local/lib/python3.6/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/b073040018/.local/lib/python3.6/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# (2, 1321967)
# (2, 660632)
# 44100
# 44100
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(x_2x[:, :sr*2], rate=sr_2x)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
